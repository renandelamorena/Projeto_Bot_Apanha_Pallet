# %%
import pandas as pd
import pyautogui as pag
import pyperclip as pcl
import time

# %%
df_cod_barras = pd.read_excel('Codigo_de_Barras.xlsx', engine='openpyxl')

# %%
df_cod_barras = df_cod_barras.astype(str)

# %%
df_cod_barras
# Out:
#       Cód.Produto                          Descrição Cód.Barras Frac.  \
# 0               1                              TESTE              nan
# 1               9                   LAVADORA PRESSÃO              nan
# 2              10                PURIFICADOR DE AGUA              nan
# 3              28                         COMPUTADOR              nan
# 4              77      ALGESTONA AC+ES 150+10MG 1AMP    7898505092506
# ...           ...                                ...              ...
# 10226    12330008     LIMPA CARINHA PET CLEAN 150 ML    7898104098718
# 10227    16730003        GEL DENTAL PET CLEAN  MENTA    7898104092655
# 10228    16930013    DEDAL CARE BUCAL PET CLEAN 30UN    7898104099043
# 10229    17030014  DEDAL CARE ORELHAS PET CLEAN 30UN    7898104099036
# 10230    17041704     DIMAG DIMALATO MAG 400MG 60CAP    7898593050860
#
#       Apan.Armaz.Cx Ender.Apan.Cx. Capac.Cx.(Unit.) Capac.Cx.(Cx.) Emb.Cx.  \
# 0               Não            nan              nan              0     nan
# 1               Não            nan              nan              0     nan
# 2               Não            nan              nan              0     nan
# 3               Não            nan              nan              0     nan
# 4               Não            nan              nan              0   100.0
# ...             ...            ...              ...            ...     ...
# 10226           Não            nan              nan              0     nan
# 10227           Não            nan              nan              0     nan
# 10228           Não            nan              nan              0     nan
# 10229           Não            nan              nan              0     nan
# 10230           Não  010-042-02-02             72.0              6    12.0
#
#       Unid.Cx.  Cód.Barras Cx.
# 0          nan             nan
# 1          nan             nan
# 2          nan             nan
# 3          nan             nan
# 4           CX             nan
# ...        ...             ...
# 10226      nan             nan
# 10227      nan             nan
# 10228      nan             nan
# 10229      nan             nan
# 10230       CX  17898593050867
#
# [10231 rows x 10 columns]

# %%
cod_tratado = '106011'

# %%
cod_barras = df_cod_barras[df_cod_barras['Cód.Produto'] == cod_tratado]['Cód.Barras Cx.'].values[0]
cod_barras
# Out:
# '07896004714578'

# %%
time.sleep(2)
pcl.copy(cod_barras)
pag.hotkey('ctrl', 'v')

# %%
07896004714578
07896004714578
